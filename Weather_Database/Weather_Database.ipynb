# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 773

# %%
cities
# Out:
# ['cabo san lucas',
#  'saldanha',
#  'punta arenas',
#  'narsaq',
#  'oga',
#  'longjiang',
#  'east london',
#  'sao joao da barra',
#  'tabuk',
#  'chicama',
#  'luderitz',
#  'bambous virieux',
#  'hobart',
#  'mataura',
#  'bururi',
#  'tumannyy',
#  'tuatapere',
#  'puerto ayora',
#  'saint-leu',
#  'mahon',
#  'atuona',
#  'cape town',
#  'ushuaia',
#  'busselton',
#  'attawapiskat',
#  'bilibino',
#  'kodiak',
#  'butaritari',
#  'eskasem',
#  'nantucket',
#  'tuktoyaktuk',
#  'mehamn',
#  'bengkulu',
#  'bredasdorp',
#  'tasiilaq',
#  'avarua',
#  'guerrero negro',
#  'marshall',
#  'jamestown',
#  'dikson',
#  'lana',
#  'panzhihua',
#  'zhigansk',
#  'bluff',
#  'mar del plata',
#  'muros',
#  'taolanaro',
#  'novyy urengoy',
#  'tautira',
#  'dzhusaly',
#  'parangan',
#  'champerico',
#  'anadyr',
#  'rikitea',
#  'padang',
#  'biltine',
#  'barrow',
#  'iquitos',
#  'sulangan',
#  'albany',
#  'torbay',
#  'tramagal',
#  'akdepe',
#  'arraial do cabo',
#  'broome',
#  'harper',
#  'barentsburg',
#  'tagusao',
#  'college',
#  'rabo de peixe',
#  'pueblo nuevo',
#  'hilo',
#  'northam',
#  'coquimbo',
#  'cedar city',
#  'vao',
#  'qaqortoq',
#  'yellowknife',
#  'imbituba',
#  'luena',
#  'airai',
#  'nome',
#  'boone',
#  'constitucion',
#  'kapaa',
#  'hammerfest',
#  'merauke',
#  'lasa',
#  'rawson',
#  'yar-sale',
#  'dudinka',
#  'cherskiy',
#  'khonuu',
#  'hambantota',
#  'vaini',
#  'saint-philippe',
#  'wulanhaote',
#  'lidkoping',
#  'vila',
#  'batagay-alyta',
#  'mehran',
#  'kieta',
#  'vondrozo',
#  'kurdzhinovo',
#  'severo-kurilsk',
#  'kununurra',
#  'richards bay',
#  'fulton',
#  'pemba',
#  'nikolskoye',
#  'bethel',
#  'roebourne',
#  'lagoa',
#  'panlaitan',
#  'egvekinot',
#  'chuy',
#  'san carlos de bariloche',
#  'hualmay',
#  'katsuura',
#  'sitka',
#  'piranhas',
#  'culiacancito',
#  'chernyshevskiy',
#  'qasigiannguit',
#  'dubrovytsya',
#  'kapit',
#  'nizhnekamsk',
#  'cidreira',
#  'oberwart',
#  'araceli',
#  'bhachau',
#  'majengo',
#  'buraydah',
#  'asfi',
#  'pangnirtung',
#  'port alfred',
#  'lebanon',
#  'nanortalik',
#  'carbonia',
#  'kamenka',
#  'kokkola',
#  'illoqqortoormiut',
#  'tuensang',
#  'aykhal',
#  'butembo',
#  'gigmoto',
#  'saint-pierre',
#  'georgetown',
#  'baruun-urt',
#  'vaitupu',
#  'qaanaaq',
#  'quilmana',
#  'marawi',
#  'dickinson',
#  'buffalo',
#  'dukat',
#  'shipunovo',
#  'saint george',
#  'ngozi',
#  'coihaique',
#  'somerset east',
#  'mayo',
#  'mahebourg',
#  'the valley',
#  'itoman',
#  'upernavik',
#  'ulaanbaatar',
#  'iqaluit',
#  'volot',
#  'duz',
#  'pandan',
#  'morondava',
#  'turukhansk',
#  'samusu',
#  'dingle',
#  'ananas',
#  'sola',
#  'tiksi',
#  'chaa-khol',
#  'new norfolk',
#  'omboue',
#  'hermanus',
#  'bargal',
#  'crowley',
#  'porto belo',
#  'nemuro',
#  'ambilobe',
#  'kamaishi',
#  'fare',
#  'miranda',
#  'belushya guba',
#  'manbij',
#  'faanui',
#  'hamilton',
#  'samarai',
#  'mys shmidta',
#  'bandarbeyla',
#  'hobyo',
#  'maracaju',
#  'miguel hidalgo',
#  'thompson',
#  'pierre',
#  'victoria',
#  'megion',
#  'sioux lookout',
#  'khatanga',
#  'huron',
#  'stolin',
#  'pisco',
#  'whitehorse',
#  'westport',
#  'sao felix do xingu',
#  'meyungs',
#  'angoche',
#  'lugo',
#  'muskegon',
#  'priyutovo',
#  'juneau',
#  'san buenaventura',
#  'lorengau',
#  'azare',
#  'kollumerland',
#  'cravo norte',
#  'seoul',
#  'aklavik',
#  'talakan',
#  'camabatela',
#  'road town',
#  'pallasovka',
#  'palabuhanratu',
#  'rohnert park',
#  'aksu',
#  'shizunai',
#  'cap malheureux',
#  'muli',
#  'yulara',
#  'beringovskiy',
#  'longlac',
#  'ostrovnoy',
#  'aberystwyth',
#  'antigonish',
#  'domoni',
#  'grand river south east',
#  'methoni',
#  'port hardy',
#  'lebu',
#  'mulege',
#  'koronowo',
#  'melilla',
#  'cuamba',
#  'chokurdakh',
#  'kavaratti',
#  'gemena',
#  'victor harbor',
#  'leh',
#  'cabedelo',
#  'tondano',
#  'salym',
#  'asilah',
#  'cairns',
#  'port-gentil',
#  'ayan',
#  'dogondoutchi',
#  'terrace',
#  'sentyabrskiy',
#  'souillac',
#  'castro',
#  'provideniya',
#  'esmeraldas',
#  'olinda',
#  'carnarvon',
#  'shelburne',
#  'pevek',
#  'leningradskiy',
#  'port elizabeth',
#  'fortuna',
#  'lata',
#  'port loko',
#  'atsiki',
#  'malindi',
#  'cheyenne',
#  'hithadhoo',
#  'hofn',
#  'tahta',
#  'bourges',
#  'jiuquan',
#  'tokur',
#  'mikhaylovka',
#  'gillette',
#  'mecca',
#  'karpathos',
#  'carhuamayo',
#  'bubaque',
#  'azimur',
#  'ancud',
#  'nuevo progreso',
#  'tual',
#  'fairbanks',
#  'adrar',
#  'klaksvik',
#  'khandyga',
#  'balurghat',
#  'manaure',
#  'pacific grove',
#  'bud',
#  'kutum',
#  'lukovetskiy',
#  'uarini',
#  'geraldton',
#  'berlevag',
#  'kaduna',
#  'longyearbyen',
#  'talara',
#  'muisne',
#  'naron',
#  'tsihombe',
#  'laguna',
#  'loudi',
#  'arlit',
#  'cedral',
#  'tambun',
#  'goderich',
#  'caravelas',
#  'dali',
#  'kruisfontein',
#  'yamoussoukro',
#  'bolsheustikinskoye',
#  'dinghai',
#  'ginda',
#  'nova olimpia',
#  'ilulissat',
#  'marcona',
#  'ribeira grande',
#  'alice springs',
#  'mayumba',
#  'waipawa',
#  'kavieng',
#  'akcaabat',
#  'ambon',
#  'nurota',
#  'ixtapa',
#  'kandla',
#  'murgab',
#  'santa barbara',
#  'telfs',
#  'maragogi',
#  'srednekolymsk',
#  'mosquera',
#  'ningan',
#  'tottori',
#  'nangong',
#  'acapulco',
#  'kuvandyk',
#  'santona',
#  'saint anthony',
#  'nelson bay',
#  'poso',
#  'lubango',
#  'wanaka',
#  'lahat',
#  'kajaani',
#  'esna',
#  'kismayo',
#  'andevoranto',
#  'latung',
#  'krasnoarmeysk',
#  'creel',
#  'petropavlovsk-kamchatskiy',
#  'matara',
#  'viareggio',
#  'paita',
#  'okhotsk',
#  'bairiki',
#  'esperance',
#  'ust-ilimsk',
#  'san patricio',
#  'kaga',
#  'marsa matruh',
#  'mount gambier',
#  'codrington',
#  'paraiso',
#  'utiroa',
#  'salinopolis',
#  'port-cartier',
#  'jaisalmer',
#  'nouadhibou',
#  'lodja',
#  'coahuayana',
#  'chara',
#  'sur',
#  'santa rosalia',
#  'port blair',
#  'port macquarie',
#  'jiayuguan',
#  'derzhavinsk',
#  'alyangula',
#  'poya',
#  'huejuquilla el alto',
#  'cortez',
#  'aden',
#  'atambua',
#  'pietarsaari',
#  'amderma',
#  'sao filipe',
#  'teguise',
#  'lavrentiya',
#  'namie',
#  'mizdah',
#  'isangel',
#  'ciechanow',
#  'haines junction',
#  'hervey bay',
#  'huejucar',
#  'fujin',
#  'karratha',
#  'norman wells',
#  'baoding',
#  'okakarara',
#  'chebarkul',
#  'salalah',
#  'maues',
#  'lazaro cardenas',
#  'cockburn town',
#  'quthing',
#  'hirara',
#  'maceio',
#  'praia',
#  'talnakh',
#  'yushu',
#  'port augusta',
#  'luwuk',
#  'waingapu',
#  'walvis bay',
#  'amapa',
#  'kloulklubed',
#  'banganan',
#  'boa vista',
#  'pasni',
#  'sept-iles',
#  'taoudenni',
#  'nioro',
#  'peddapalli',
#  'shitanjing',
#  'nushki',
#  'saleaula',
#  'chapais',
#  'mezen',
#  'moth',
#  'poum',
#  'dunedin',
#  'port lincoln',
#  'vandra',
#  'krasnoyarsk-66',
#  'abalak',
#  'mizan teferi',
#  'deputatskiy',
#  'port keats',
#  'price',
#  'taltal',
#  'salamanca',
#  'asyut',
#  'viedma',
#  'mandalgovi',
#  'ponta do sol',
#  'bad sackingen',
#  'soe',
#  'tiznit',
#  'maghama',
#  'tukan',
#  'namibe',
#  'mufumbwe',
#  'samalaeulu',
#  'itarema',
#  'ahipara',
#  'payson',
#  'kaa-khem',
#  'harsin',
#  'andenes',
#  'kenai',
#  'falkoping',
#  'camaqua',
#  'kozienice',
#  'rudnichnyy',
#  'eirunepe',
#  'kalmunai',
#  'majene',
#  'sakakah',
#  'shiraz',
#  'haimen',
#  'general roca',
#  'halifax',
#  'batouri',
#  'iralaya',
#  'freeport',
#  'barsovo',
#  'udachnyy',
#  'nizhneyansk',
#  'shenjiamen',
#  'trinidad',
#  'nianzishan',
#  'saskylakh',
#  'budogoshch',
#  'mareeba',
#  'puerto ayacucho',
#  'lufilufi',
#  'simbahan',
#  'chore',
#  'churapcha',
#  'macamic',
#  'suntar',
#  'villa alemana',
#  'armidale',
#  'cairo',
#  'akureyri',
#  'le port',
#  'vila franca do campo',
#  'lagos',
#  'aleksandrov gay',
#  'araouane',
#  'mapimi',
#  'kaeo',
#  'alofi',
#  'dilla',
#  'tarudant',
#  'miragoane',
#  'tomatlan',
#  'panguna',
#  'axim',
#  'mount isa',
#  'bundaberg',
#  'galle',
#  'iseyin',
#  'fort nelson',
#  'tynda',
#  'awbari',
#  'fukuma',
#  'katima mulilo',
#  'saint-augustin',
#  'crestview',
#  'guajara-mirim',
#  'xuanhua',
#  'saint-louis',
#  'buta',
#  'najran',
#  'jiancheng',
#  'toliary',
#  'hermiston',
#  'zhangye',
#  'dzerzhinsk',
#  'devils lake',
#  'el puerto de santa maria',
#  'fairlie',
#  'haicheng',
#  'palu',
#  'kirkenaer',
#  'lethem',
#  'khovu-aksy',
#  'kibala',
#  'tavrichanka',
#  'paamiut',
#  'faya',
#  'portland',
#  'dubrovnik',
#  'bodoco',
#  'yefimovskiy',
#  'misratah',
#  'turka',
#  'gamba',
#  'vila velha',
#  'birjand',
#  'lakeway',
#  'candawaga',
#  'bacolod',
#  'tarragona',
#  'limbang',
#  'kanker',
#  'tauberbischofsheim',
#  'hasaki',
#  'nikolayevsk-na-amure',
#  'sovetskiy',
#  'hastings',
#  'tabiauea',
#  'asau',
#  'hokitika',
#  'flin flon',
#  'orsk',
#  'micheweni',
#  'bathsheba',
#  'berbera',
#  'liverpool',
#  'santa maria',
#  'asmara',
#  'warqla',
#  'sol-iletsk',
#  'yumen',
#  'plettenberg bay',
#  'ayia trias',
#  'kovur',
#  'windhoek',
#  'pitsunda',
#  'borgarnes',
#  'quang ngai',
#  'kachikau',
#  'phan rang',
#  'kahului',
#  'west wendover',
#  'oil city',
#  'porirua',
#  'los llanos de aridane',
#  'wasilla',
#  'apatity',
#  'yusva',
#  'chadiza',
#  'ampanihy',
#  'katangli',
#  'bur gabo',
#  'gobabis',
#  'wawa',
#  'benito juarez',
#  'chake chake',
#  'vyazniki',
#  'kyren',
#  'lompoc',
#  'iskateley',
#  'umzimvubu',
#  'husavik',
#  'akyab',
#  'korla',
#  'inhambane',
#  'gat',
#  'tir pol',
#  'meulaboh',
#  'shingu',
#  'touros',
#  'buin',
#  'pitimbu',
#  'naze',
#  'halalo',
#  'rapid valley',
#  'chebsara',
#  'ratnagiri',
#  'olafsvik',
#  'burnie',
#  'jiwani',
#  'les herbiers',
#  'damnagar',
#  'solsvik',
#  'chitral',
#  'necochea',
#  'milnathort',
#  'mumford',
#  'peniche',
#  'teeli',
#  'hede',
#  'texarkana',
#  'tura',
#  'lisala',
#  'jalu',
#  'san jeronimito',
#  'sibolga',
#  'cooma',
#  'prince rupert',
#  'tessalit',
#  'san ramon de la nueva oran',
#  'sanmenxia',
#  'blythe',
#  'south lake tahoe',
#  'quzhou',
#  'cayenne',
#  'mushie',
#  'kurilsk',
#  'paldiski',
#  'henties bay',
#  'kerteh',
#  'santa rosa',
#  'laramie',
#  'dunmore town',
#  'okha',
#  'panguipulli',
#  'morogoro',
#  'neiafu',
#  'havelock',
#  'lebedyn',
#  'katsina',
#  'stekolnyy',
#  'kushiro',
#  'komsomolskiy',
#  'ola',
#  'yanam',
#  'mackenzie',
#  'balkanabat',
#  'mosjoen',
#  'vardo',
#  'malinovoye ozero',
#  'pilibanga',
#  'dhidhdhoo',
#  'kawalu',
#  'kharitonovo',
#  'ozgon',
#  'ksenyevka',
#  'bartica',
#  'san isidro',
#  'ust-shonosha',
#  'puerto madryn',
#  'brive-la-gaillarde',
#  'tsentralnyy',
#  'jiddah',
#  'alta floresta',
#  'pringsewu',
#  'moyale',
#  'vostok',
#  'azangaro',
#  'shibetsu',
#  'mergui',
#  'yershichi',
#  'burica',
#  'arman',
#  'vieux fort',
#  'krasnogorsk',
#  'matagami',
#  'blagoveshchensk',
#  'ornskoldsvik',
#  'skibotn',
#  'luba',
#  'buchanan',
#  'beloha',
#  'ust-kamchatsk',
#  'diffa',
#  'litayen',
#  'karaul',
#  'havre',
#  'pacifica',
#  'port antonio',
#  'siavonga',
#  'birin',
#  'ourinhos',
#  'kroya',
#  'kashi',
#  'louisbourg',
#  'gazli',
#  'beberibe',
#  'ankang',
#  'sagvag',
#  'neryungri',
#  'mutsamudu',
#  'devin',
#  'carballo',
#  'fukue',
#  'pau',
#  'moerai',
#  'constantine',
#  'umm kaddadah',
#  'vanimo',
#  'fort dodge',
#  'la ronge',
#  'smithers',
#  'manchester',
#  'daru',
#  'maloshuyka',
#  'lugovaya',
#  'tingrela',
#  'vallenar',
#  'dwarka',
#  'mingaora',
#  'rocha',
#  'felanitx',
#  'narasannapeta',
#  'samborondon',
#  'sundsvall',
#  'kimbe',
#  'the pas',
#  'rungata',
#  'samaipata']

# %%
# Create API url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cabo san lucas
# Processing Record 2 of Set 1 | saldanha
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | narsaq
# Processing Record 5 of Set 1 | oga
# Processing Record 6 of Set 1 | longjiang
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | sao joao da barra
# Processing Record 9 of Set 1 | tabuk
# Processing Record 10 of Set 1 | chicama
# Processing Record 11 of Set 1 | luderitz
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | bururi
# Processing Record 16 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 1 | tuatapere
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | saint-leu
# Processing Record 20 of Set 1 | mahon
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 1 | bilibino
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 1 | nantucket
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | mehamn
# Processing Record 33 of Set 1 | bengkulu
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | guerrero negro
# Processing Record 38 of Set 1 | marshall
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | lana
# Processing Record 42 of Set 1 | panzhihua
# Processing Record 43 of Set 1 | zhigansk
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | muros
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | novyy urengoy
# Processing Record 49 of Set 1 | tautira
# Processing Record 50 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 2 | parangan
# Processing Record 2 of Set 2 | champerico
# Processing Record 3 of Set 2 | anadyr
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | padang
# Processing Record 6 of Set 2 | biltine
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | iquitos
# Processing Record 9 of Set 2 | sulangan
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | tramagal
# Processing Record 13 of Set 2 | akdepe
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | broome
# Processing Record 16 of Set 2 | harper
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | tagusao
# Processing Record 19 of Set 2 | college
# Processing Record 20 of Set 2 | rabo de peixe
# Processing Record 21 of Set 2 | pueblo nuevo
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | northam
# Processing Record 24 of Set 2 | coquimbo
# Processing Record 25 of Set 2 | cedar city
# Processing Record 26 of Set 2 | vao
# Processing Record 27 of Set 2 | qaqortoq
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | imbituba
# Processing Record 30 of Set 2 | luena
# Processing Record 31 of Set 2 | airai
# Processing Record 32 of Set 2 | nome
# Processing Record 33 of Set 2 | boone
# Processing Record 34 of Set 2 | constitucion
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | hammerfest
# Processing Record 37 of Set 2 | merauke
# Processing Record 38 of Set 2 | lasa
# Processing Record 39 of Set 2 | rawson
# Processing Record 40 of Set 2 | yar-sale
# Processing Record 41 of Set 2 | dudinka
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 2 | hambantota
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 48 of Set 2 | lidkoping
# Processing Record 49 of Set 2 | vila
# Processing Record 50 of Set 2 | batagay-alyta
# Processing Record 1 of Set 3 | mehran
# Processing Record 2 of Set 3 | kieta
# Processing Record 3 of Set 3 | vondrozo
# Processing Record 4 of Set 3 | kurdzhinovo
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | kununurra
# Processing Record 7 of Set 3 | richards bay
# Processing Record 8 of Set 3 | fulton
# Processing Record 9 of Set 3 | pemba
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | bethel
# Processing Record 12 of Set 3 | roebourne
# Processing Record 13 of Set 3 | lagoa
# Processing Record 14 of Set 3 | panlaitan
# Processing Record 15 of Set 3 | egvekinot
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | san carlos de bariloche
# Processing Record 18 of Set 3 | hualmay
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | sitka
# Processing Record 21 of Set 3 | piranhas
# Processing Record 22 of Set 3 | culiacancito
# Processing Record 23 of Set 3 | chernyshevskiy
# Processing Record 24 of Set 3 | qasigiannguit
# Processing Record 25 of Set 3 | dubrovytsya
# Processing Record 26 of Set 3 | kapit
# Processing Record 27 of Set 3 | nizhnekamsk
# Processing Record 28 of Set 3 | cidreira
# Processing Record 29 of Set 3 | oberwart
# Processing Record 30 of Set 3 | araceli
# Processing Record 31 of Set 3 | bhachau
# Processing Record 32 of Set 3 | majengo
# Processing Record 33 of Set 3 | buraydah
# Processing Record 34 of Set 3 | asfi
# Processing Record 35 of Set 3 | pangnirtung
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | lebanon
# Processing Record 38 of Set 3 | nanortalik
# Processing Record 39 of Set 3 | carbonia
# Processing Record 40 of Set 3 | kamenka
# Processing Record 41 of Set 3 | kokkola
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | tuensang
# Processing Record 44 of Set 3 | aykhal
# Processing Record 45 of Set 3 | butembo
# Processing Record 46 of Set 3 | gigmoto
# Processing Record 47 of Set 3 | saint-pierre
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | baruun-urt
# Processing Record 50 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 4 | qaanaaq
# Processing Record 2 of Set 4 | quilmana
# Processing Record 3 of Set 4 | marawi
# Processing Record 4 of Set 4 | dickinson
# Processing Record 5 of Set 4 | buffalo
# Processing Record 6 of Set 4 | dukat
# Processing Record 7 of Set 4 | shipunovo
# Processing Record 8 of Set 4 | saint george
# Processing Record 9 of Set 4 | ngozi
# Processing Record 10 of Set 4 | coihaique
# Processing Record 11 of Set 4 | somerset east
# Processing Record 12 of Set 4 | mayo
# Processing Record 13 of Set 4 | mahebourg
# Processing Record 14 of Set 4 | the valley
# Processing Record 15 of Set 4 | itoman
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | ulaanbaatar
# Processing Record 18 of Set 4 | iqaluit
# Processing Record 19 of Set 4 | volot
# Processing Record 20 of Set 4 | duz
# City not found. Skipping...
# Processing Record 21 of Set 4 | pandan
# Processing Record 22 of Set 4 | morondava
# Processing Record 23 of Set 4 | turukhansk
# Processing Record 24 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 4 | dingle
# Processing Record 26 of Set 4 | ananas
# Processing Record 27 of Set 4 | sola
# Processing Record 28 of Set 4 | tiksi
# Processing Record 29 of Set 4 | chaa-khol
# City not found. Skipping...
# Processing Record 30 of Set 4 | new norfolk
# Processing Record 31 of Set 4 | omboue
# Processing Record 32 of Set 4 | hermanus
# Processing Record 33 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 4 | crowley
# Processing Record 35 of Set 4 | porto belo
# Processing Record 36 of Set 4 | nemuro
# Processing Record 37 of Set 4 | ambilobe
# Processing Record 38 of Set 4 | kamaishi
# Processing Record 39 of Set 4 | fare
# Processing Record 40 of Set 4 | miranda
# Processing Record 41 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 4 | manbij
# Processing Record 43 of Set 4 | faanui
# Processing Record 44 of Set 4 | hamilton
# Processing Record 45 of Set 4 | samarai
# Processing Record 46 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 4 | bandarbeyla
# Processing Record 48 of Set 4 | hobyo
# Processing Record 49 of Set 4 | maracaju
# Processing Record 50 of Set 4 | miguel hidalgo
# Processing Record 1 of Set 5 | thompson
# Processing Record 2 of Set 5 | pierre
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | megion
# Processing Record 5 of Set 5 | sioux lookout
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | huron
# Processing Record 8 of Set 5 | stolin
# Processing Record 9 of Set 5 | pisco
# Processing Record 10 of Set 5 | whitehorse
# Processing Record 11 of Set 5 | westport
# Processing Record 12 of Set 5 | sao felix do xingu
# Processing Record 13 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 5 | angoche
# Processing Record 15 of Set 5 | lugo
# Processing Record 16 of Set 5 | muskegon
# Processing Record 17 of Set 5 | priyutovo
# Processing Record 18 of Set 5 | juneau
# Processing Record 19 of Set 5 | san buenaventura
# Processing Record 20 of Set 5 | lorengau
# Processing Record 21 of Set 5 | azare
# Processing Record 22 of Set 5 | kollumerland
# City not found. Skipping...
# Processing Record 23 of Set 5 | cravo norte
# Processing Record 24 of Set 5 | seoul
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | talakan
# Processing Record 27 of Set 5 | camabatela
# Processing Record 28 of Set 5 | road town
# Processing Record 29 of Set 5 | pallasovka
# Processing Record 30 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 5 | rohnert park
# Processing Record 32 of Set 5 | aksu
# Processing Record 33 of Set 5 | shizunai
# Processing Record 34 of Set 5 | cap malheureux
# Processing Record 35 of Set 5 | muli
# Processing Record 36 of Set 5 | yulara
# Processing Record 37 of Set 5 | beringovskiy
# Processing Record 38 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 5 | ostrovnoy
# Processing Record 40 of Set 5 | aberystwyth
# Processing Record 41 of Set 5 | antigonish
# Processing Record 42 of Set 5 | domoni
# Processing Record 43 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 5 | methoni
# Processing Record 45 of Set 5 | port hardy
# Processing Record 46 of Set 5 | lebu
# Processing Record 47 of Set 5 | mulege
# Processing Record 48 of Set 5 | koronowo
# Processing Record 49 of Set 5 | melilla
# Processing Record 50 of Set 5 | cuamba
# Processing Record 1 of Set 6 | chokurdakh
# Processing Record 2 of Set 6 | kavaratti
# Processing Record 3 of Set 6 | gemena
# Processing Record 4 of Set 6 | victor harbor
# Processing Record 5 of Set 6 | leh
# Processing Record 6 of Set 6 | cabedelo
# Processing Record 7 of Set 6 | tondano
# Processing Record 8 of Set 6 | salym
# Processing Record 9 of Set 6 | asilah
# Processing Record 10 of Set 6 | cairns
# Processing Record 11 of Set 6 | port-gentil
# Processing Record 12 of Set 6 | ayan
# Processing Record 13 of Set 6 | dogondoutchi
# Processing Record 14 of Set 6 | terrace
# Processing Record 15 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 6 | souillac
# Processing Record 17 of Set 6 | castro
# Processing Record 18 of Set 6 | provideniya
# Processing Record 19 of Set 6 | esmeraldas
# Processing Record 20 of Set 6 | olinda
# Processing Record 21 of Set 6 | carnarvon
# Processing Record 22 of Set 6 | shelburne
# Processing Record 23 of Set 6 | pevek
# Processing Record 24 of Set 6 | leningradskiy
# Processing Record 25 of Set 6 | port elizabeth
# Processing Record 26 of Set 6 | fortuna
# Processing Record 27 of Set 6 | lata
# Processing Record 28 of Set 6 | port loko
# Processing Record 29 of Set 6 | atsiki
# City not found. Skipping...
# Processing Record 30 of Set 6 | malindi
# Processing Record 31 of Set 6 | cheyenne
# Processing Record 32 of Set 6 | hithadhoo
# Processing Record 33 of Set 6 | hofn
# Processing Record 34 of Set 6 | tahta
# Processing Record 35 of Set 6 | bourges
# Processing Record 36 of Set 6 | jiuquan
# Processing Record 37 of Set 6 | tokur
# Processing Record 38 of Set 6 | mikhaylovka
# Processing Record 39 of Set 6 | gillette
# Processing Record 40 of Set 6 | mecca
# Processing Record 41 of Set 6 | karpathos
# Processing Record 42 of Set 6 | carhuamayo
# Processing Record 43 of Set 6 | bubaque
# Processing Record 44 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 6 | ancud
# Processing Record 46 of Set 6 | nuevo progreso
# Processing Record 47 of Set 6 | tual
# Processing Record 48 of Set 6 | fairbanks
# Processing Record 49 of Set 6 | adrar
# Processing Record 50 of Set 6 | klaksvik
# Processing Record 1 of Set 7 | khandyga
# Processing Record 2 of Set 7 | balurghat
# Processing Record 3 of Set 7 | manaure
# Processing Record 4 of Set 7 | pacific grove
# Processing Record 5 of Set 7 | bud
# Processing Record 6 of Set 7 | kutum
# Processing Record 7 of Set 7 | lukovetskiy
# Processing Record 8 of Set 7 | uarini
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | berlevag
# Processing Record 11 of Set 7 | kaduna
# Processing Record 12 of Set 7 | longyearbyen
# Processing Record 13 of Set 7 | talara
# Processing Record 14 of Set 7 | muisne
# Processing Record 15 of Set 7 | naron
# Processing Record 16 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 7 | laguna
# Processing Record 18 of Set 7 | loudi
# Processing Record 19 of Set 7 | arlit
# Processing Record 20 of Set 7 | cedral
# Processing Record 21 of Set 7 | tambun
# Processing Record 22 of Set 7 | goderich
# Processing Record 23 of Set 7 | caravelas
# Processing Record 24 of Set 7 | dali
# Processing Record 25 of Set 7 | kruisfontein
# Processing Record 26 of Set 7 | yamoussoukro
# Processing Record 27 of Set 7 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 28 of Set 7 | dinghai
# Processing Record 29 of Set 7 | ginda
# Processing Record 30 of Set 7 | nova olimpia
# Processing Record 31 of Set 7 | ilulissat
# Processing Record 32 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 7 | ribeira grande
# Processing Record 34 of Set 7 | alice springs
# Processing Record 35 of Set 7 | mayumba
# Processing Record 36 of Set 7 | waipawa
# Processing Record 37 of Set 7 | kavieng
# Processing Record 38 of Set 7 | akcaabat
# Processing Record 39 of Set 7 | ambon
# Processing Record 40 of Set 7 | nurota
# Processing Record 41 of Set 7 | ixtapa
# Processing Record 42 of Set 7 | kandla
# Processing Record 43 of Set 7 | murgab
# Processing Record 44 of Set 7 | santa barbara
# Processing Record 45 of Set 7 | telfs
# Processing Record 46 of Set 7 | maragogi
# Processing Record 47 of Set 7 | srednekolymsk
# Processing Record 48 of Set 7 | mosquera
# Processing Record 49 of Set 7 | ningan
# City not found. Skipping...
# Processing Record 50 of Set 7 | tottori
# Processing Record 1 of Set 8 | nangong
# Processing Record 2 of Set 8 | acapulco
# Processing Record 3 of Set 8 | kuvandyk
# Processing Record 4 of Set 8 | santona
# Processing Record 5 of Set 8 | saint anthony
# Processing Record 6 of Set 8 | nelson bay
# Processing Record 7 of Set 8 | poso
# Processing Record 8 of Set 8 | lubango
# Processing Record 9 of Set 8 | wanaka
# Processing Record 10 of Set 8 | lahat
# Processing Record 11 of Set 8 | kajaani
# Processing Record 12 of Set 8 | esna
# Processing Record 13 of Set 8 | kismayo
# Processing Record 14 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 15 of Set 8 | latung
# Processing Record 16 of Set 8 | krasnoarmeysk
# Processing Record 17 of Set 8 | creel
# Processing Record 18 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 8 | matara
# Processing Record 20 of Set 8 | viareggio
# Processing Record 21 of Set 8 | paita
# Processing Record 22 of Set 8 | okhotsk
# Processing Record 23 of Set 8 | bairiki
# Processing Record 24 of Set 8 | esperance
# Processing Record 25 of Set 8 | ust-ilimsk
# Processing Record 26 of Set 8 | san patricio
# Processing Record 27 of Set 8 | kaga
# Processing Record 28 of Set 8 | marsa matruh
# Processing Record 29 of Set 8 | mount gambier
# Processing Record 30 of Set 8 | codrington
# Processing Record 31 of Set 8 | paraiso
# Processing Record 32 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 8 | salinopolis
# Processing Record 34 of Set 8 | port-cartier
# Processing Record 35 of Set 8 | jaisalmer
# Processing Record 36 of Set 8 | nouadhibou
# Processing Record 37 of Set 8 | lodja
# Processing Record 38 of Set 8 | coahuayana
# Processing Record 39 of Set 8 | chara
# Processing Record 40 of Set 8 | sur
# Processing Record 41 of Set 8 | santa rosalia
# Processing Record 42 of Set 8 | port blair
# Processing Record 43 of Set 8 | port macquarie
# Processing Record 44 of Set 8 | jiayuguan
# Processing Record 45 of Set 8 | derzhavinsk
# Processing Record 46 of Set 8 | alyangula
# Processing Record 47 of Set 8 | poya
# Processing Record 48 of Set 8 | huejuquilla el alto
# Processing Record 49 of Set 8 | cortez
# Processing Record 50 of Set 8 | aden
# Processing Record 1 of Set 9 | atambua
# Processing Record 2 of Set 9 | pietarsaari
# Processing Record 3 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 9 | sao filipe
# Processing Record 5 of Set 9 | teguise
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | namie
# Processing Record 8 of Set 9 | mizdah
# Processing Record 9 of Set 9 | isangel
# Processing Record 10 of Set 9 | ciechanow
# Processing Record 11 of Set 9 | haines junction
# Processing Record 12 of Set 9 | hervey bay
# Processing Record 13 of Set 9 | huejucar
# Processing Record 14 of Set 9 | fujin
# Processing Record 15 of Set 9 | karratha
# Processing Record 16 of Set 9 | norman wells
# Processing Record 17 of Set 9 | baoding
# Processing Record 18 of Set 9 | okakarara
# Processing Record 19 of Set 9 | chebarkul
# Processing Record 20 of Set 9 | salalah
# Processing Record 21 of Set 9 | maues
# Processing Record 22 of Set 9 | lazaro cardenas
# Processing Record 23 of Set 9 | cockburn town
# Processing Record 24 of Set 9 | quthing
# Processing Record 25 of Set 9 | hirara
# Processing Record 26 of Set 9 | maceio
# Processing Record 27 of Set 9 | praia
# Processing Record 28 of Set 9 | talnakh
# Processing Record 29 of Set 9 | yushu
# Processing Record 30 of Set 9 | port augusta
# Processing Record 31 of Set 9 | luwuk
# Processing Record 32 of Set 9 | waingapu
# Processing Record 33 of Set 9 | walvis bay
# Processing Record 34 of Set 9 | amapa
# Processing Record 35 of Set 9 | kloulklubed
# Processing Record 36 of Set 9 | banganan
# Processing Record 37 of Set 9 | boa vista
# Processing Record 38 of Set 9 | pasni
# Processing Record 39 of Set 9 | sept-iles
# Processing Record 40 of Set 9 | taoudenni
# Processing Record 41 of Set 9 | nioro
# Processing Record 42 of Set 9 | peddapalli
# Processing Record 43 of Set 9 | shitanjing
# Processing Record 44 of Set 9 | nushki
# Processing Record 45 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 9 | chapais
# Processing Record 47 of Set 9 | mezen
# Processing Record 48 of Set 9 | moth
# Processing Record 49 of Set 9 | poum
# Processing Record 50 of Set 9 | dunedin
# Processing Record 1 of Set 10 | port lincoln
# Processing Record 2 of Set 10 | vandra
# Processing Record 3 of Set 10 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 4 of Set 10 | abalak
# Processing Record 5 of Set 10 | mizan teferi
# Processing Record 6 of Set 10 | deputatskiy
# Processing Record 7 of Set 10 | port keats
# Processing Record 8 of Set 10 | price
# Processing Record 9 of Set 10 | taltal
# Processing Record 10 of Set 10 | salamanca
# Processing Record 11 of Set 10 | asyut
# Processing Record 12 of Set 10 | viedma
# Processing Record 13 of Set 10 | mandalgovi
# Processing Record 14 of Set 10 | ponta do sol
# Processing Record 15 of Set 10 | bad sackingen
# Processing Record 16 of Set 10 | soe
# Processing Record 17 of Set 10 | tiznit
# Processing Record 18 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 19 of Set 10 | tukan
# Processing Record 20 of Set 10 | namibe
# Processing Record 21 of Set 10 | mufumbwe
# Processing Record 22 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 10 | itarema
# Processing Record 24 of Set 10 | ahipara
# Processing Record 25 of Set 10 | payson
# Processing Record 26 of Set 10 | kaa-khem
# Processing Record 27 of Set 10 | harsin
# Processing Record 28 of Set 10 | andenes
# Processing Record 29 of Set 10 | kenai
# Processing Record 30 of Set 10 | falkoping
# City not found. Skipping...
# Processing Record 31 of Set 10 | camaqua
# Processing Record 32 of Set 10 | kozienice
# Processing Record 33 of Set 10 | rudnichnyy
# Processing Record 34 of Set 10 | eirunepe
# Processing Record 35 of Set 10 | kalmunai
# Processing Record 36 of Set 10 | majene
# Processing Record 37 of Set 10 | sakakah
# Processing Record 38 of Set 10 | shiraz
# Processing Record 39 of Set 10 | haimen
# Processing Record 40 of Set 10 | general roca
# Processing Record 41 of Set 10 | halifax
# Processing Record 42 of Set 10 | batouri
# Processing Record 43 of Set 10 | iralaya
# Processing Record 44 of Set 10 | freeport
# Processing Record 45 of Set 10 | barsovo
# Processing Record 46 of Set 10 | udachnyy
# Processing Record 47 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 10 | shenjiamen
# Processing Record 49 of Set 10 | trinidad
# Processing Record 50 of Set 10 | nianzishan
# Processing Record 1 of Set 11 | saskylakh
# Processing Record 2 of Set 11 | budogoshch
# Processing Record 3 of Set 11 | mareeba
# Processing Record 4 of Set 11 | puerto ayacucho
# Processing Record 5 of Set 11 | lufilufi
# Processing Record 6 of Set 11 | simbahan
# Processing Record 7 of Set 11 | chore
# City not found. Skipping...
# Processing Record 8 of Set 11 | churapcha
# Processing Record 9 of Set 11 | macamic
# Processing Record 10 of Set 11 | suntar
# Processing Record 11 of Set 11 | villa alemana
# Processing Record 12 of Set 11 | armidale
# Processing Record 13 of Set 11 | cairo
# Processing Record 14 of Set 11 | akureyri
# Processing Record 15 of Set 11 | le port
# Processing Record 16 of Set 11 | vila franca do campo
# Processing Record 17 of Set 11 | lagos
# Processing Record 18 of Set 11 | aleksandrov gay
# Processing Record 19 of Set 11 | araouane
# Processing Record 20 of Set 11 | mapimi
# Processing Record 21 of Set 11 | kaeo
# Processing Record 22 of Set 11 | alofi
# Processing Record 23 of Set 11 | dilla
# Processing Record 24 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 11 | miragoane
# Processing Record 26 of Set 11 | tomatlan
# Processing Record 27 of Set 11 | panguna
# Processing Record 28 of Set 11 | axim
# Processing Record 29 of Set 11 | mount isa
# Processing Record 30 of Set 11 | bundaberg
# Processing Record 31 of Set 11 | galle
# Processing Record 32 of Set 11 | iseyin
# Processing Record 33 of Set 11 | fort nelson
# Processing Record 34 of Set 11 | tynda
# Processing Record 35 of Set 11 | awbari
# Processing Record 36 of Set 11 | fukuma
# Processing Record 37 of Set 11 | katima mulilo
# Processing Record 38 of Set 11 | saint-augustin
# Processing Record 39 of Set 11 | crestview
# Processing Record 40 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 41 of Set 11 | xuanhua
# Processing Record 42 of Set 11 | saint-louis
# Processing Record 43 of Set 11 | buta
# Processing Record 44 of Set 11 | najran
# Processing Record 45 of Set 11 | jiancheng
# Processing Record 46 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 11 | hermiston
# Processing Record 48 of Set 11 | zhangye
# Processing Record 49 of Set 11 | dzerzhinsk
# Processing Record 50 of Set 11 | devils lake
# Processing Record 1 of Set 12 | el puerto de santa maria
# Processing Record 2 of Set 12 | fairlie
# Processing Record 3 of Set 12 | haicheng
# Processing Record 4 of Set 12 | palu
# Processing Record 5 of Set 12 | kirkenaer
# Processing Record 6 of Set 12 | lethem
# Processing Record 7 of Set 12 | khovu-aksy
# Processing Record 8 of Set 12 | kibala
# Processing Record 9 of Set 12 | tavrichanka
# Processing Record 10 of Set 12 | paamiut
# Processing Record 11 of Set 12 | faya
# Processing Record 12 of Set 12 | portland
# Processing Record 13 of Set 12 | dubrovnik
# Processing Record 14 of Set 12 | bodoco
# City not found. Skipping...
# Processing Record 15 of Set 12 | yefimovskiy
# City not found. Skipping...
# Processing Record 16 of Set 12 | misratah
# Processing Record 17 of Set 12 | turka
# Processing Record 18 of Set 12 | gamba
# Processing Record 19 of Set 12 | vila velha
# Processing Record 20 of Set 12 | birjand
# Processing Record 21 of Set 12 | lakeway
# Processing Record 22 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 23 of Set 12 | bacolod
# Processing Record 24 of Set 12 | tarragona
# Processing Record 25 of Set 12 | limbang
# Processing Record 26 of Set 12 | kanker
# Processing Record 27 of Set 12 | tauberbischofsheim
# Processing Record 28 of Set 12 | hasaki
# Processing Record 29 of Set 12 | nikolayevsk-na-amure
# Processing Record 30 of Set 12 | sovetskiy
# Processing Record 31 of Set 12 | hastings
# Processing Record 32 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 12 | asau
# Processing Record 34 of Set 12 | hokitika
# Processing Record 35 of Set 12 | flin flon
# Processing Record 36 of Set 12 | orsk
# Processing Record 37 of Set 12 | micheweni
# Processing Record 38 of Set 12 | bathsheba
# Processing Record 39 of Set 12 | berbera
# Processing Record 40 of Set 12 | liverpool
# Processing Record 41 of Set 12 | santa maria
# Processing Record 42 of Set 12 | asmara
# Processing Record 43 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 12 | sol-iletsk
# Processing Record 45 of Set 12 | yumen
# Processing Record 46 of Set 12 | plettenberg bay
# Processing Record 47 of Set 12 | ayia trias
# Processing Record 48 of Set 12 | kovur
# Processing Record 49 of Set 12 | windhoek
# Processing Record 50 of Set 12 | pitsunda
# Processing Record 1 of Set 13 | borgarnes
# Processing Record 2 of Set 13 | quang ngai
# Processing Record 3 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 4 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 13 | kahului
# Processing Record 6 of Set 13 | west wendover
# Processing Record 7 of Set 13 | oil city
# Processing Record 8 of Set 13 | porirua
# Processing Record 9 of Set 13 | los llanos de aridane
# Processing Record 10 of Set 13 | wasilla
# Processing Record 11 of Set 13 | apatity
# Processing Record 12 of Set 13 | yusva
# City not found. Skipping...
# Processing Record 13 of Set 13 | chadiza
# Processing Record 14 of Set 13 | ampanihy
# Processing Record 15 of Set 13 | katangli
# Processing Record 16 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 13 | gobabis
# Processing Record 18 of Set 13 | wawa
# Processing Record 19 of Set 13 | benito juarez
# Processing Record 20 of Set 13 | chake chake
# Processing Record 21 of Set 13 | vyazniki
# Processing Record 22 of Set 13 | kyren
# Processing Record 23 of Set 13 | lompoc
# Processing Record 24 of Set 13 | iskateley
# Processing Record 25 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 13 | husavik
# Processing Record 27 of Set 13 | akyab
# Processing Record 28 of Set 13 | korla
# Processing Record 29 of Set 13 | inhambane
# Processing Record 30 of Set 13 | gat
# Processing Record 31 of Set 13 | tir pol
# City not found. Skipping...
# Processing Record 32 of Set 13 | meulaboh
# Processing Record 33 of Set 13 | shingu
# Processing Record 34 of Set 13 | touros
# Processing Record 35 of Set 13 | buin
# Processing Record 36 of Set 13 | pitimbu
# Processing Record 37 of Set 13 | naze
# Processing Record 38 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 13 | rapid valley
# Processing Record 40 of Set 13 | chebsara
# Processing Record 41 of Set 13 | ratnagiri
# Processing Record 42 of Set 13 | olafsvik
# Processing Record 43 of Set 13 | burnie
# Processing Record 44 of Set 13 | jiwani
# Processing Record 45 of Set 13 | les herbiers
# Processing Record 46 of Set 13 | damnagar
# Processing Record 47 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 48 of Set 13 | chitral
# Processing Record 49 of Set 13 | necochea
# Processing Record 50 of Set 13 | milnathort
# Processing Record 1 of Set 14 | mumford
# Processing Record 2 of Set 14 | peniche
# Processing Record 3 of Set 14 | teeli
# Processing Record 4 of Set 14 | hede
# Processing Record 5 of Set 14 | texarkana
# Processing Record 6 of Set 14 | tura
# Processing Record 7 of Set 14 | lisala
# Processing Record 8 of Set 14 | jalu
# Processing Record 9 of Set 14 | san jeronimito
# Processing Record 10 of Set 14 | sibolga
# Processing Record 11 of Set 14 | cooma
# Processing Record 12 of Set 14 | prince rupert
# Processing Record 13 of Set 14 | tessalit
# Processing Record 14 of Set 14 | san ramon de la nueva oran
# Processing Record 15 of Set 14 | sanmenxia
# Processing Record 16 of Set 14 | blythe
# Processing Record 17 of Set 14 | south lake tahoe
# Processing Record 18 of Set 14 | quzhou
# Processing Record 19 of Set 14 | cayenne
# Processing Record 20 of Set 14 | mushie
# Processing Record 21 of Set 14 | kurilsk
# Processing Record 22 of Set 14 | paldiski
# Processing Record 23 of Set 14 | henties bay
# Processing Record 24 of Set 14 | kerteh
# City not found. Skipping...
# Processing Record 25 of Set 14 | santa rosa
# Processing Record 26 of Set 14 | laramie
# Processing Record 27 of Set 14 | dunmore town
# Processing Record 28 of Set 14 | okha
# Processing Record 29 of Set 14 | panguipulli
# Processing Record 30 of Set 14 | morogoro
# Processing Record 31 of Set 14 | neiafu
# Processing Record 32 of Set 14 | havelock
# Processing Record 33 of Set 14 | lebedyn
# Processing Record 34 of Set 14 | katsina
# Processing Record 35 of Set 14 | stekolnyy
# City not found. Skipping...
# Processing Record 36 of Set 14 | kushiro
# Processing Record 37 of Set 14 | komsomolskiy
# Processing Record 38 of Set 14 | ola
# Processing Record 39 of Set 14 | yanam
# Processing Record 40 of Set 14 | mackenzie
# Processing Record 41 of Set 14 | balkanabat
# Processing Record 42 of Set 14 | mosjoen
# Processing Record 43 of Set 14 | vardo
# Processing Record 44 of Set 14 | malinovoye ozero
# Processing Record 45 of Set 14 | pilibanga
# Processing Record 46 of Set 14 | dhidhdhoo
# Processing Record 47 of Set 14 | kawalu
# Processing Record 48 of Set 14 | kharitonovo
# Processing Record 49 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 50 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 1 of Set 15 | bartica
# Processing Record 2 of Set 15 | san isidro
# Processing Record 3 of Set 15 | ust-shonosha
# Processing Record 4 of Set 15 | puerto madryn
# Processing Record 5 of Set 15 | brive-la-gaillarde
# Processing Record 6 of Set 15 | tsentralnyy
# City not found. Skipping...
# Processing Record 7 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 8 of Set 15 | alta floresta
# Processing Record 9 of Set 15 | pringsewu
# Processing Record 10 of Set 15 | moyale
# Processing Record 11 of Set 15 | vostok
# Processing Record 12 of Set 15 | azangaro
# Processing Record 13 of Set 15 | shibetsu
# Processing Record 14 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 15 of Set 15 | yershichi
# Processing Record 16 of Set 15 | burica
# City not found. Skipping...
# Processing Record 17 of Set 15 | arman
# Processing Record 18 of Set 15 | vieux fort
# Processing Record 19 of Set 15 | krasnogorsk
# Processing Record 20 of Set 15 | matagami
# Processing Record 21 of Set 15 | blagoveshchensk
# Processing Record 22 of Set 15 | ornskoldsvik
# Processing Record 23 of Set 15 | skibotn
# Processing Record 24 of Set 15 | luba
# Processing Record 25 of Set 15 | buchanan
# Processing Record 26 of Set 15 | beloha
# Processing Record 27 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 15 | diffa
# Processing Record 29 of Set 15 | litayen
# City not found. Skipping...
# Processing Record 30 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 15 | havre
# Processing Record 32 of Set 15 | pacifica
# Processing Record 33 of Set 15 | port antonio
# Processing Record 34 of Set 15 | siavonga
# Processing Record 35 of Set 15 | birin
# Processing Record 36 of Set 15 | ourinhos
# Processing Record 37 of Set 15 | kroya
# Processing Record 38 of Set 15 | kashi
# Processing Record 39 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 15 | gazli
# Processing Record 41 of Set 15 | beberibe
# Processing Record 42 of Set 15 | ankang
# Processing Record 43 of Set 15 | sagvag
# Processing Record 44 of Set 15 | neryungri
# Processing Record 45 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 15 | devin
# Processing Record 47 of Set 15 | carballo
# Processing Record 48 of Set 15 | fukue
# Processing Record 49 of Set 15 | pau
# Processing Record 50 of Set 15 | moerai
# Processing Record 1 of Set 16 | constantine
# Processing Record 2 of Set 16 | umm kaddadah
# Processing Record 3 of Set 16 | vanimo
# Processing Record 4 of Set 16 | fort dodge
# Processing Record 5 of Set 16 | la ronge
# Processing Record 6 of Set 16 | smithers
# Processing Record 7 of Set 16 | manchester
# Processing Record 8 of Set 16 | daru
# Processing Record 9 of Set 16 | maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 16 | lugovaya
# Processing Record 11 of Set 16 | tingrela
# City not found. Skipping...
# Processing Record 12 of Set 16 | vallenar
# Processing Record 13 of Set 16 | dwarka
# Processing Record 14 of Set 16 | mingaora
# Processing Record 15 of Set 16 | rocha
# Processing Record 16 of Set 16 | felanitx
# Processing Record 17 of Set 16 | narasannapeta
# Processing Record 18 of Set 16 | samborondon
# Processing Record 19 of Set 16 | sundsvall
# Processing Record 20 of Set 16 | kimbe
# Processing Record 21 of Set 16 | the pas
# Processing Record 22 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 16 | samaipata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Description"]
city_data_df = city_data_df[new_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Cabo San Lucas      MX  22.8909 -109.9124     94.60        61
# 1          Saldanha      ZA -33.0117   17.9442     46.45        83
# 2      Punta Arenas      CL -53.1500  -70.9167     41.11        87
# 3            Narsaq      GL  60.9167  -46.0500     52.02        86
# 4               Oga      IT  46.4631   10.3470     66.88        82
# ..              ...     ...      ...       ...       ...       ...
# 698     Samborondon      EC  -1.9500  -79.7333     82.40        45
# 699       Sundsvall      SE  62.3913   17.3063     63.97        80
# 700           Kimbe      PG  -5.5502  150.1429     79.47        78
# 701         The Pas      CA  53.8251 -101.2541     66.22        72
# 702       Samaipata      BO -18.1500  -63.8667     51.10        94
#
#      Cloudiness  Wind Speed Weather Description
# 0             0       11.50           clear sky
# 1            55        7.18       broken clouds
# 2            75        0.00       broken clouds
# 3            95        3.27     overcast clouds
# 4            68        3.20       broken clouds
# ..          ...         ...                 ...
# 698          77        2.57       broken clouds
# 699         100        2.30     overcast clouds
# 700          54        3.15       broken clouds
# 701         100       13.80     overcast clouds
# 702          80        2.86       broken clouds
#
# [703 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
